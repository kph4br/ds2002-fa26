# %% [markdown]
# <a href="https://colab.research.google.com/github/kph4br/ds2002-fa26/blob/main/notebooks/01-foundations/2026-09-04-submission-drill-and-fix-a-broken-notebook-lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DS2002 · Submission Drill and Fix a Broken Notebook
#
# **Lab — 2026-09-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 02 — Submission Drill and Fix a Broken Notebook
#
# You have inherited a notebook that does not run. This is the most common way you will meet other people's code, so it is worth practicing deliberately.
#
# Seven cells below are broken. Five throw an error, and two return a wrong answer without complaining at all — those are the dangerous ones. Fix all seven, prove your fixes with assertions, then push through the full submit loop.
#
# **Submit in Canvas:** repository link and notebook link.

# %% [markdown]
# ### How to read an error before you fix it
#
# Python's traceback is read **bottom up**. The last line names the exception and the problem; the line above it points at your code.
#
# ```
# Traceback (most recent call last):
#   File "<stdin>", line 2, in <module>
#     print(greeting)
# NameError: name 'greeting' is not defined
# ```
#
# Four exceptions cover most of what you will hit this semester:
#
# | Exception | Usually means |
# |---|---|
# | `NameError` | The variable was never created, or the cell that created it never ran |
# | `TypeError` | You mixed types — text where a number belongs is the classic |
# | `KeyError` | That column or dictionary key does not exist. Check spelling and case |
# | `FileNotFoundError` | The path is wrong for *this* environment |
#
# For each fix below, write one sentence in the markdown cell saying what was actually wrong. "It works now" is not a diagnosis.

# %% [markdown]
# ### Bug 1 — a name that does not exist

# %%
# TODO: fix so this prints a greeting
greeting = "Hiya!"
print(greeting)
# Out:
# Hiya!

# %% [markdown]
# **What was wrong:** You can't print greeting when nothing has been assigned for greeting to print. Once you assign something to greeting, Python won't raise a NameError anymore.

# %% [markdown]
# ### Bug 2 — text where a number belongs
#
# This should print `30`. Note that `'10' + 20` and `'10' + '20'` fail in different ways — make sure you know which one you are looking at.

# %%
# TODO: fix so total is the number 30
total = int('10') + 20
print(total)
# Out:
# 30

# %% [markdown]
# **What was wrong:** '10' is type string but 20 is type integer, so the + operator crated a TypeError. You can't add a string and an integer together, so you have to convert the string to integer and then the addition will work.

# %% [markdown]
# ### Bug 3 — off the end of a list

# %%
items = ['burger', 'poncho', 'hat']

# TODO: print the LAST item, and do it in a way that still works
#       if someone adds a fourth item tomorrow
print(items[-1])
# Out:
# hat

# %% [markdown]
# **What was wrong:** items only contains values for indices 0-2 (because of zero indexing in Python), so items[3] referrs to an index items doesn't have. This raised an IndexError, so the fix is to call for the index at items[-1], which always refers to the last element of the list regardless of length or additional additions to the length.

# %% [markdown]
# ### Bug 4 — no error, wrong answer
#
# This is supposed to be the average. It prints a number, and the number is wrong.

# %%
nums = [2, 4, 6, 8]
average = sum(nums) / len(nums)
print('average:', average)
# Out:
# average: 5.0

# %% [markdown]
# **What was wrong:** The code computed the average incorrectly because it divided by the hard-coded number 2 instead of the actual length of the list. You can hard code the divisor to calcualate the average, but the safer option is to divide by len(nums) because len() is dynamic and will update if you change the length of the list. In this case you needed the divisor to be 4, so len(nums) will be 4.

# %% [markdown]
# ### Bug 5 — a table that cannot exist

# %%
import pandas as pd

df = pd.DataFrame({'item': ['a', 'b'], 'price': [1, 2]})
print(df)
# Out:
#   item  price
# 0    a      1
# 1    b      2

# %% [markdown]
# **What was wrong:** The key item had 2 values, but the key price had 3, so pandas couldn't build a table and raised a ValueError. Editing price so that both keys had the same number of values (deleting the 3 at the end of the list so that it only was of length 2) fixes the mismatch.

# %% [markdown]
# ### Bug 6 — the answer changes when you re-run it
#
# Run the next cell three times and watch the total move. Then fix it using what you built Wednesday: leave the source data alone and derive a new column from it. Your fix must give the same total on every run.

# %%
sales = pd.DataFrame({
    'game': ['NC State', 'Louisville'],
    'units': [1450, 1610],
})

# TODO: rewrite these two lines so re-running cannot change the answer
sales['units_scaled'] = sales['units'] * 1.05
print('total units:', round(sales['units_scaled'].sum(), 2))
# Out:
# total units: 3213.0

# %%
# Proof — this must print the same number three times
for _ in range(3):
    # TODO: rebuild from the raw values and print your total
    total_units = round((sales['units'] * 1.05).sum(), 2)
    print(total_units)
# Out:
# 3213.0
# 3213.0
# 3213.0

# %% [markdown]
# **What was wrong:** The code chunk sales['units'] = sales['units'] * 1.05 was replacing the original units numbers with the increased ones. Consequently, every time you rean the cell again, the code used the already mulitiplied numbers and increased them by 5% again (that's why the total kept climbing). The fix is to leave the original units column alone and put the multiplied numbers in a new column called units_scaled, that way no matter how many times you run it, Python is always doing the math from the same starting numbers.

# %% [markdown]
# ### Bug 7 — a path from someone else's laptop
#
# This notebook was written on a machine you do not have. Fix it with the pattern from Wednesday's studio: look for the file, and fall back to the inline sample so the notebook still runs for whoever opens it next.

# %%
import os
from io import StringIO

SAMPLE = '''game,units\nNC State,1450\nLouisville,1610\n'''

# TODO: replace this with a lookup + fallback that works anywhere
path = '/Users/someone/Desktop/gameday_orders.csv'
if os.path.exists(path):
  orders = pd.read_csv(path)
else:
  orders = pd.read_csv(StringIO(SAMPLE))
orders
# Out:
#          game  units
# 0    NC State   1450
# 1  Louisville   1610

# %% [markdown]
# **What was wrong:** The path pointed at a file on someone else's laptop, so it raised a FileNotFoundError. Checking os.path.exists() first and then falling back to the inline SAMPLE data lets the notebook run anywhere.

# %% [markdown]
# ### Part 8 — prove the fixes
#
# Assertions are how you state what must be true. If one fails, the notebook stops and tells you which claim broke — much better than scrolling for a wrong number.
#
# **TODO:** uncomment each line and make them all pass.

# %%
assert isinstance(greeting, str) and greeting != ''
assert total == 30
assert items[-1] == 'hat'
assert average == 5
assert len(df) == 2
assert len(orders) >= 2
print('All checks passed.')
# Out:
# All checks passed.

# %% [markdown]
# ### Part 9 — the submit drill
#
# This is the part that is actually being graded on process. Do it in order.
#
# 1. **Restart the kernel and Run All.** Zero errors, top to bottom.
# 2. Download the notebook and put it in your repo under `notebooks/01-foundations/`, named `2026-09-04 — Submission Drill and Fix a Broken Notebook — Lab.ipynb`.
# 3. Commit with a message that says what you did, then push.
# 4. Confirm on github.com that the file is there and opens.
# 5. Fill in the cell below and submit both links in Canvas.
#
# **TODO:** fill in the four values and make the check pass.

# %%
import re

repo_url = 'https://github.com/kph4br/ds2002-fa26'
commit_sha = '7043c30'
notebook_link = 'https://github.com/kph4br/ds2002-fa26/blob/main/notebooks/01-foundations/2026-09-04-submission-drill-and-fix-a-broken-notebook-lab.ipynb'
ran_restart_and_run_all = True   # TODO: set True after you actually do it

checks = {
    'repo URL is a github.com URL':
        repo_url.startswith('https://github.com/')
        and repo_url.count('/') >= 4,
    'commit hash looks like a hash':
        bool(re.fullmatch(r'[0-9a-f]{7,40}', commit_sha.strip())),
    'notebook link filled in':
        notebook_link.startswith('http'),
    'restarted and ran all':
        ran_restart_and_run_all is True,
}

for label, passed in checks.items():
    print('PASS' if passed else 'FAIL', '-', label)

print()
print('Ready to submit:', all(checks.values()))
# Out:
# PASS - repo URL is a github.com URL
# PASS - commit hash looks like a hash
# PASS - notebook link filled in
# PASS - restarted and ran all
#
# Ready to submit: True

# %% [markdown]
# #### Write-up
#
# Bugs 4 and 6 did not raise an error. In a few sentences: how would you catch that class of bug in a project where you do not already know the right answer? Name something concrete you could add to a notebook.

# %% [markdown]
# To catch a bug in a project where I don't already know the right answer, I could add checks that test whether the result makes sense instead of checking for a very specific number match. As an example, I could add an assertion that an average calculation has to be between the smallest and largest number in a list, and if it's not, that'd tell me something is broken (but I wouldn't necessarily have to know the exact correct average). For a bug like in question 6 where re-running the same cell kept changing the answer, I could add a check that runs the calculation twice or multiple times and make sure every answer gives the exact same result. If that isn't the case, that's a sign something is being changed by accident and I need to go and fix it.

# %% [markdown]
# ### Stretch
#
# Write a `check_orders(df)` function that raises a clear error if the frame is missing either expected column, has zero rows, or contains a negative value in `units`. Then call it on `orders`. This is the shape of validation you will want in both projects.

# %%
# stretch

def check_orders(df):
  expected_columns = {'game', 'units'}
  missing = expected_columns - set(df.columns)
  if missing:
    raise ValueError(f"orders is missing expected columns: {missing}")
  if len(df) == 0:
    raise ValueError("orders has zero rows")
  if (df['units'] < 0).any():
    raise ValueError("orders contains a negative value in 'units'")
  print("orders passed all checks!")

check_orders(orders)
# Out:
# orders passed all checks!
